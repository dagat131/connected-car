# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import seaborn as sns

D201506 = pd.read_csv('201506_201506_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201512 = pd.read_csv('201512_201512_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201606 = pd.read_csv('201606_201606_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201612 = pd.read_csv('201612_201612_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201706 = pd.read_csv('201706_201706_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201712 = pd.read_csv('201712_201712_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201806 = pd.read_csv('201806_201806_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201812 = pd.read_csv('201812_201812_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201906 = pd.read_csv('201906_201906_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')
D201912 = pd.read_csv('201912_201912_연령별인구현황_연간.csv',thousands=',',encoding = 'cp949')
D202006 = pd.read_csv('202006_202006_연령별인구현황_월간.csv',thousands=',',encoding = 'cp949')

################ 데이터 리스트에 담는다.
D_list=[D201506,D201512,D201606,D201612,D201706,D201712,D201806,D201812,D201906,D201912,D202006]
D_list_s=[]
D_list_b=[]

print(D202006)
# Out:
# 행정구역  2020년06월_계_총인구수  2020년06월_계_연령구간인구수  \
# 0     대구광역시  (2700000000)          2427954             2427954
# 1   대구광역시 중구 (2711000000)            76984               76984
# 2   대구광역시 동구 (2714000000)           342627              342627
# 3   대구광역시 서구 (2717000000)           172802              172802
# 4   대구광역시 남구 (2720000000)           147482              147482
# 5   대구광역시 북구 (2723000000)           438608              438608
# 6  대구광역시 수성구 (2726000000)           426919              426919
# 7  대구광역시 달서구 (2729000000)           565378              565378
# 8  대구광역시 달성군 (2771000000)           257154              257154
#
#    2020년06월_계_0~9세  2020년06월_계_10~19세  2020년06월_계_20~29세  2020년06월_계_30~39세  \
# 0           183631             230453             322265             300366
# 1             5342               5097              11866              11041
# 2            25923              27046              41737              44676
# ...

# %%
############### 데이터 for문으로 빼기 돌리기
for a in D_list:
    D_list1=np.array(a)
    D_list11=np.delete(D_list1,(0), axis=1)
    D_list_s.append(D_list11)
# D201506_1 = np.array(D201506)
# D201506_11 = np.delete(D201506_1,(0), axis=1)
# D201512_1 = np.array(D201512)
# D201512_11 = np.delete(D201512_1,(0), axis=1)
for a in range(0,10):
    b=np.subtract(D_list_s[a],D_list_s[a+1])
    D_list_b.append(-b)
print(len(D_list_b))
# a=np.subtract(D201506_11,D201512_11)
# a.shape
# b=np.ones((9,13),dtype='<U11')

# print(type(b[1][1]))
# print(type(a[1][1]))
# Out:
# 10

# %%
df1=[]
for i in range(0,10): 
    df =pd.DataFrame(D_list_b[i],columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])
    df1.append(df)
df1
# Out:
# [        총계 연령구간인구수   0~9  10~19 20~29  30~39  40~49 50~59 60~69  70~79 80~89  \
#  대구   -3308   -3308  -395  -8648  1512  -5038  -3962  3162  8811  -1216  2219
#  중구     135     135     9   -177    62     14     35   -59   207    -80   117
#  동구     -14     -14    -7  -1026   192   -689   -294   190  1375   -194   401
#  서구   -1874   -1874  -126   -959  -156   -589  -1037   -18   935   -140   222
#  남구   -1316   -1316  -149   -572  -130   -510   -413  -292   605   -130   252
#  북구    -328    -328  -152  -1654   414  -1032   -407   902  1392   -136   313
#  수성구   -361    -361   -52  -1354   473   -895   -592   526  1365   -259   362
#  달서구  -3591   -3591  -675  -2561   150  -2174  -1530  1001  2037   -274   370
#  달성군   4041    4041   757   -345   507    837    276   912   895     -3   182
#
#      90~99 100세 이상
#  대구    224      23
#  중구      4       3
#  동구     32       6
#  서구     -8       2
#  남구     19       4
#  북구     30       2
#  수성구    63       2
#  달서구    64       1
# ...

# %% [markdown]
# # 각 이어지는 년도 별(2015 ~ 2016 ~ 2017 ~ 2018 ~ 2019, 201912~202006) 데이이터분석

# %%
D201606_1 = np.array(D201606)
D201606_11 = np.delete(D201606_1,(0), axis=1)
D201512_1 = np.array(D201512)
D201512_11 = np.delete(D201512_1,(0), axis=1)

a6=np.subtract(D201512_11,D201606_11)
a6.shape
b6=np.ones((9,13),dtype='<U11')

print(type(b5[1][1]))
print(type(a5[1][1]))

# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a5[i][j]>0:
            b5[i][j]=str(a5[i][j])+"증가"
        elif a5[i][j]<0:
            b5[i][j]=str(a5[i][j]*(-1))+"감소"
        else :
            b5[i][j]="인구유지"

print("2019년도 증감추세")
df2020 =pd.DataFrame(a5,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])

print("2019년도 증감추세")
df2020_1 =pd.DataFrame(b5,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])



import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2020.index)
prob=np.array(df2020["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2020년도 증감추세")

plt.show()
# Out:
# <class 'numpy.str_'>
# <class 'int'>
# 2019년도 증감추세
# 2019년도 증감추세

# %% [markdown]
# #각 년도 별(2015, 2016, 2017, 2018, 2019, 201912~202006) 데이이터분석

# %%
D202006_1 = np.array(D202006)
D202006_11 = np.delete(D202006_1,(0), axis=1)
D201912_1 = np.array(D201912)
D201912_11 = np.delete(D201912_1,(0), axis=1)

a5=np.subtract(D202006_11,D201912_11)
a5.shape
b5=np.ones((9,13),dtype='<U11')

print(type(b5[1][1]))
print(type(a5[1][1]))

# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a5[i][j]>0:
            b5[i][j]=str(a5[i][j])+"증가"
        elif a5[i][j]<0:
            b5[i][j]=str(a5[i][j]*(-1))+"감소"
        else :
            b5[i][j]="인구유지"

print("2019년도 증감추세")
df2020 =pd.DataFrame(a5,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])

print("2019년도 증감추세")
df2020_1 =pd.DataFrame(b5,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])



import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2020.index)
prob=np.array(df2020["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2020년도 증감추세")

plt.show()
# Out:
# <class 'numpy.str_'>
# <class 'int'>
# 2019년도 증감추세
# 2019년도 증감추세

# %%
D202006_1 = np.array(D202006)
D202006_11 = np.delete(D202006_1,(0), axis=1)
D201912_1 = np.array(D201912)
D201912_11 = np.delete(D201912_1,(0), axis=1)

a5=np.subtract(D201912_11,D202006_11)
a5.shape
b5=np.ones((9,13),dtype='<U11')

print(type(b5[1][1]))
print(type(a5[1][1]))

# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a5[i][j]>0:
            b5[i][j]=str(a5[i][j])+"증가"
        elif a5[i][j]<0:
            b5[i][j]=str(a5[i][j]*(-1))+"감소"
        else :
            b5[i][j]="인구유지"

print("2019년도 증감추세")
df2020 =pd.DataFrame(a5,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])

print("2019년도 증감추세")
df2020_1 =pd.DataFrame(b5,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])



import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2020.index)
prob=np.array(df2020["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2020년도 증감추세")

plt.show()
# Out:
# <class 'numpy.str_'>
# <class 'int'>
# 2019년도 증감추세
# 2019년도 증감추세

# %%
D201906_1 = np.array(D201906)
D201906_11 = np.delete(D201906_1,(0), axis=1)
D201912_1 = np.array(D201912)
D201912_11 = np.delete(D201912_1,(0), axis=1)

a4=np.subtract(D201906_11,D201912_11)
a4.shape
b4=np.ones((9,13),dtype='<U11')

print(type(b4[1][1]))
print(type(a4[1][1]))

# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a4[i][j]>0:
            b4[i][j]=str(a4[i][j])+"증가"
        elif a4[i][j]<0:
            b4[i][j]=str(a4[i][j]*(-1))+"감소"
        else :
            b4[i][j]="인구유지"

print("2019년도 증감추세")
df2019 =pd.DataFrame(a4,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])

print("2019년도 증감추세")
df2019_1 =pd.DataFrame(b4,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])



import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2019.index)
prob=np.array(df2019["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2019년도 증감추세")

plt.show()
# Out:
# <class 'numpy.str_'>
# <class 'int'>
# 2019년도 증감추세
# 2019년도 증감추세

# %%
D201806_1 = np.array(D201806)
D201806_11 = np.delete(D201806_1,(0), axis=1)
D201812_1 = np.array(D201812)
D201812_11 = np.delete(D201812_1,(0), axis=1)

a3=np.subtract(D201806_11,D201812_11)
a3.shape
b3=np.ones((9,13),dtype='<U11')

print(type(b3[1][1]))
print(type(a3[1][1]))

# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a3[i][j]>0:
            b3[i][j]=str(a3[i][j])+"증가"
        elif a3[i][j]<0:
            b3[i][j]=str(a3[i][j]*(-1))+"감소"
        else :
            b3[i][j]="인구유지"

print("2018년도 증감추세")
df2018 =pd.DataFrame(a3,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])

print("2018년도 증감추세")
df2018_1 =pd.DataFrame(b3,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])



import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2018.index)
prob=np.array(df2018["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2018년도 증감추세")

plt.show()
# Out:
# <class 'numpy.str_'>
# <class 'int'>
# 2018년도 증감추세
# 2018년도 증감추세

# %%
D201706_1 = np.array(D201706)
D201706_11 = np.delete(D201706_1,(0), axis=1)
D201712_1 = np.array(D201712)
D201712_11 = np.delete(D201712_1,(0), axis=1)

a2=np.subtract(D201706_11,D201712_11)
a2.shape
b2=np.ones((9,13),dtype='<U11')

print(type(b2[1][1]))
print(type(a2[1][1]))
# Out:
# <class 'numpy.str_'>
# <class 'int'>

# %%
# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a2[i][j]>0:
            b2[i][j]=str(a2[i][j])+"증가"
        elif a2[i][j]<0:
            b2[i][j]=str(a2[i][j]*(-1))+"감소"
        else :
            b2[i][j]="인구유지"
print(b2)
# Out:
# [['6754증가' '6754증가' '4126증가' '5328증가' '544감소' '5648증가' '4277증가' '173증가'
#   '7096감소' '2956감소' '1893감소' '283감소' '26감소']
#  ['61감소' '61감소' '94감소' '13감소' '127감소' '6감소' '61증가' '134증가' '71증가' '41감소'
#   '26감소' '21감소' '1증가']
#  ['1774증가' '1774증가' '912증가' '505증가' '106증가' '1419증가' '464증가' '339증가'
#   '1026감소' '524감소' '363감소' '56감소' '2감소']
#  ['4515증가' '4515증가' '624증가' '849증가' '560증가' '1300증가' '1307증가' '638증가'
#   '335감소' '250감소' '144감소' '29감소' '5감소']
#  ['1931증가' '1931증가' '438증가' '365증가' '53증가' '910증가' '476증가' '368증가'
#   '344감소' '131감소' '169감소' '35감소' '인구유지']
#  ['1955감소' '1955감소' '561증가' '998증가' '894감소' '386증가' '인구유지' '663감소'
#   '1403감소' '577감소' '323감소' '40감소' '인구유지']
#  ['4695증가' '4695증가' '1264증가' '1228증가' '311증가' '1450증가' '1574증가' '376증가'
#   '844감소' '298감소' '332감소' '23감소' '11감소']
#  ['8985증가' '8985증가' '2180증가' '2051증가' '1216증가' '3242증가' '2260증가' '539증가'
#   '1537감소' '601감소' '319감소' '39감소' '7감소']
#  ['13130감소' '13130감소' '1759감소' '655감소' '1769감소' '3053감소' '1865감소'
# ...

# %%
print("2017년도 증감추세")
df2017 =pd.DataFrame(a2,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])
df2017
# Out:
# 2017년도 증감추세
#          총계 연령구간인구수    0~9 10~19  20~29  30~39  40~49  50~59  60~69  70~79  \
# 대구     6754    6754   4126  5328   -544   5648   4277    173  -7096  -2956
# 중구      -61     -61    -94   -13   -127     -6     61    134     71    -41
# 동구     1774    1774    912   505    106   1419    464    339  -1026   -524
# 서구     4515    4515    624   849    560   1300   1307    638   -335   -250
# 남구     1931    1931    438   365     53    910    476    368   -344   -131
# 북구    -1955   -1955    561   998   -894    386      0   -663  -1403   -577
# 수성구    4695    4695   1264  1228    311   1450   1574    376   -844   -298
# 달서구    8985    8985   2180  2051   1216   3242   2260    539  -1537   -601
# 달성군  -13130  -13130  -1759  -655  -1769  -3053  -1865  -1558  -1678   -534
#
#      80~89 90~99 100세 이상
# 대구   -1893  -283     -26
# 중구     -26   -21       1
# 동구    -363   -56      -2
# 서구    -144   -29      -5
# 남구    -169   -35       0
# 북구    -323   -40       0
# ...

# %%
print("2017년도 증감추세")
df2017_1 =pd.DataFrame(b2,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])
df2017
# Out:
# 2017년도 증감추세
#          총계 연령구간인구수    0~9 10~19  20~29  30~39  40~49  50~59  60~69  70~79  \
# 대구     6754    6754   4126  5328   -544   5648   4277    173  -7096  -2956
# 중구      -61     -61    -94   -13   -127     -6     61    134     71    -41
# 동구     1774    1774    912   505    106   1419    464    339  -1026   -524
# 서구     4515    4515    624   849    560   1300   1307    638   -335   -250
# 남구     1931    1931    438   365     53    910    476    368   -344   -131
# 북구    -1955   -1955    561   998   -894    386      0   -663  -1403   -577
# 수성구    4695    4695   1264  1228    311   1450   1574    376   -844   -298
# 달서구    8985    8985   2180  2051   1216   3242   2260    539  -1537   -601
# 달성군  -13130  -13130  -1759  -655  -1769  -3053  -1865  -1558  -1678   -534
#
#      80~89 90~99 100세 이상
# 대구   -1893  -283     -26
# 중구     -26   -21       1
# 동구    -363   -56      -2
# 서구    -144   -29      -5
# 남구    -169   -35       0
# 북구    -323   -40       0
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2017.index)
prob=np.array(df2017["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2017년도 증감추세")

plt.show()

# %%
D201606_1 = np.array(D201606)
D201606_11 = np.delete(D201606_1,(0), axis=1)
D201612_1 = np.array(D201512)
D201612_11 = np.delete(D201612_1,(0), axis=1)

# a1 = D201606_11 - D201612_11 # sbstract와 같음
a1=np.subtract(D201606_11,D201612_11)
a1 # 16년 6월데이터와 16년 12월 데이터를 빼서 증감추세를 저장
a1.shape
b1=np.ones((9,13),dtype='<U11') # b1은 ones를 통해 1로 바꿔줌. 이유는 for문을 돌려 증감 추세를 표현하기 위함.

print(type(b1[1][1]))
print(type(a1[1][1]))
# Out:
# <class 'numpy.str_'>
# <class 'int'>

# %%
D201606_1 = np.array(D201606)
D201606_11 = np.delete(D201606_1,(0), axis=1)
D201612_1 = np.array(D201512)
D201612_11 = np.delete(D201612_1,(0), axis=1)

# a1 = D201606_11 - D201612_11 # sbstract와 같음
a1=np.subtract(D201606_11,D201612_11)
a1 # 16년 6월데이터와 16년 12월 데이터를 빼서 증감추세를 저장
a1.shape
b1=np.ones((9,13),dtype='<U11') # b1은 ones를 통해 1로 바꿔줌. 이유는 for문을 돌려 증감 추세를 표현하기 위함.

print(type(b1[1][1]))
print(type(a1[1][1]))
# Out:
# <class 'numpy.str_'>
# <class 'int'>

# %%
# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a1[i][j]>0:
            b1[i][j]=str(a1[i][j])+"증가"
        elif a1[i][j]<0:
            b1[i][j]=str(a1[i][j]*(-1))+"감소"
        else :
            b1[i][j]="인구유지"
print(b1)
# Out:
# [['2965감소' '2965감소' '745감소' '8250감소' '1485증가' '4820감소' '4656감소' '1923증가'
#   '9593증가' '535감소' '2807증가' '211증가' '22증가']
#  ['196감소' '196감소' '31증가' '134감소' '164증가' '254감소' '6감소' '214감소' '153증가'
#   '60감소' '108증가' '14증가' '2증가']
#  ['1268증가' '1268증가' '173증가' '744감소' '390증가' '496감소' '118감소' '79증가'
#   '1517증가' '55감소' '514증가' '2증가' '6증가']
#  ['3137감소' '3137감소' '250감소' '942감소' '599감소' '949감소' '1024감소' '293감소'
#   '776증가' '127감소' '251증가' '16증가' '4증가']
#  ['2214감소' '2214감소' '278감소' '582감소' '244감소' '759감소' '446감소' '449감소'
#   '500증가' '175감소' '215증가' '3증가' '1증가']
#  ['1036감소' '1036감소' '871감소' '1291감소' '533증가' '1448감소' '895감소' '932증가'
#   '1560증가' '16증가' '393증가' '27증가' '8증가']
#  ['2597감소' '2597감소' '422감소' '2148감소' '301증가' '1213감소' '1158감소' '191증가'
#   '1502증가' '199감소' '475증가' '71증가' '3증가']
#  ['7354감소' '7354감소' '1469감소' '2873감소' '430감소' '2959감소' '2403감소' '116증가'
#   '2141증가' '120감소' '594증가' '51증가' '2감소']
#  ['12301증가' '12301증가' '2341증가' '464증가' '1370증가' '3258증가' '1394증가'
# ...

# %%
print("2016년도 증감추세")
df2016 =pd.DataFrame(a1,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])
df2016
# Out:
# 2016년도 증감추세
#         총계 연령구간인구수    0~9  10~19 20~29  30~39  40~49 50~59 60~69 70~79 80~89  \
# 대구   -2965   -2965   -745  -8250  1485  -4820  -4656  1923  9593  -535  2807
# 중구    -196    -196     31   -134   164   -254     -6  -214   153   -60   108
# 동구    1268    1268    173   -744   390   -496   -118    79  1517   -55   514
# 서구   -3137   -3137   -250   -942  -599   -949  -1024  -293   776  -127   251
# 남구   -2214   -2214   -278   -582  -244   -759   -446  -449   500  -175   215
# 북구   -1036   -1036   -871  -1291   533  -1448   -895   932  1560    16   393
# 수성구  -2597   -2597   -422  -2148   301  -1213  -1158   191  1502  -199   475
# 달서구  -7354   -7354  -1469  -2873  -430  -2959  -2403   116  2141  -120   594
# 달성군  12301   12301   2341    464  1370   3258   1394  1561  1444   185   257
#
#     90~99 100세 이상
# 대구    211      22
# 중구     14       2
# 동구      2       6
# 서구     16       4
# 남구      3       1
# 북구     27       8
# 수성구    71       3
# 달서구    51      -2
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2016.index)
prob=np.array(df2016["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)
plt.title("2016년도 증감추세")

plt.show()

# %%
import seaborn as sns

# 시각화 라이브러리를 이용한 피처간의 scatter plot을 출력합니다.
sns.set(style='whitegrid', context='notebook')
sns.pairplot(df2016[["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"]], height=1)
plt.show()

# %%
D201506_1 = np.array(D201506)
D201506_11 = np.delete(D201506_1,(0), axis=1)
D201512_1 = np.array(D201512)
D201512_11 = np.delete(D201512_1,(0), axis=1)
a=np.subtract(D201506_11,D201512_11)
a.shape
b=np.ones((9,13),dtype='<U11')

print(type(b[1][1]))
print(type(a[1][1]))
# Out:
# <class 'numpy.str_'>
# <class 'int'>

# %%
a.shape
# Out:
# (9, 13)

# %%
# 9x13 행렬을 for문을 돌려 0보다 크면 증가, 0보다 작으면 감소, 변화가 없다면 유지.
for i in range(0,9):
    for j in range(0,13):
        if a[i][j]>0:
            b[i][j]=str(a[i][j])+"증가"
        elif a[i][j]<0:
            b[i][j]=str(a[i][j]*(-1))+"감소"
        else :
            b[i][j]="인구유지"
print(b)
# Out:
# [['3308증가' '3308증가' '395증가' '8648증가' '1512감소' '5038증가' '3962증가' '3162감소'
#   '8811감소' '1216증가' '2219감소' '224감소' '23감소']
#  ['135감소' '135감소' '9감소' '177증가' '62감소' '14감소' '35감소' '59증가' '207감소'
#   '80증가' '117감소' '4감소' '3감소']
#  ['14증가' '14증가' '7증가' '1026증가' '192감소' '689증가' '294증가' '190감소' '1375감소'
#   '194증가' '401감소' '32감소' '6감소']
#  ['1874증가' '1874증가' '126증가' '959증가' '156증가' '589증가' '1037증가' '18증가'
#   '935감소' '140증가' '222감소' '8증가' '2감소']
#  ['1316증가' '1316증가' '149증가' '572증가' '130증가' '510증가' '413증가' '292증가'
#   '605감소' '130증가' '252감소' '19감소' '4감소']
#  ['328증가' '328증가' '152증가' '1654증가' '414감소' '1032증가' '407증가' '902감소'
#   '1392감소' '136증가' '313감소' '30감소' '2감소']
#  ['361증가' '361증가' '52증가' '1354증가' '473감소' '895증가' '592증가' '526감소'
#   '1365감소' '259증가' '362감소' '63감소' '2감소']
#  ['3591증가' '3591증가' '675증가' '2561증가' '150감소' '2174증가' '1530증가' '1001감소'
#   '2037감소' '274증가' '370감소' '64감소' '1감소']
#  ['4041감소' '4041감소' '757감소' '345증가' '507감소' '837감소' '276감소' '912감소'
# ...

# %%
df2015 =pd.DataFrame(a,columns=["총계","연령구간인구수","0~9","10~19","20~29","30~39","40~49","50~59","60~69","70~79","80~89","90~99","100세 이상"],index=["대구","중구","동구","서구","남구","북구","수성구","달서구","달성군"])
df2015
# Out:
#         총계 연령구간인구수   0~9 10~19  20~29 30~39 40~49  50~59  60~69 70~79  80~89  \
# 대구    3308    3308   395  8648  -1512  5038  3962  -3162  -8811  1216  -2219
# 중구    -135    -135    -9   177    -62   -14   -35     59   -207    80   -117
# 동구      14      14     7  1026   -192   689   294   -190  -1375   194   -401
# 서구    1874    1874   126   959    156   589  1037     18   -935   140   -222
# 남구    1316    1316   149   572    130   510   413    292   -605   130   -252
# 북구     328     328   152  1654   -414  1032   407   -902  -1392   136   -313
# 수성구    361     361    52  1354   -473   895   592   -526  -1365   259   -362
# 달서구   3591    3591   675  2561   -150  2174  1530  -1001  -2037   274   -370
# 달성군  -4041   -4041  -757   345   -507  -837  -276   -912   -895     3   -182
#
#     90~99 100세 이상
# 대구   -224     -23
# 중구     -4      -3
# 동구    -32      -6
# 서구      8      -2
# 남구    -19      -4
# 북구    -30      -2
# 수성구   -63      -2
# 달서구   -64      -1
# 달성군   -20      -3

# %%
df2015_1 =pd.DataFrame(b,columns=D201506.columns[1:])
df2015_1
# Out:
#   2015년06월_계_총인구수 2015년06월_계_연령구간인구수 2015년06월_계_0~9세 2015년06월_계_10~19세  \
# 0          3308증가             3308증가           395증가            8648증가
# 1           135감소              135감소             9감소             177증가
# 2            14증가               14증가             7증가            1026증가
# 3          1874증가             1874증가           126증가             959증가
# 4          1316증가             1316증가           149증가             572증가
# 5           328증가              328증가           152증가            1654증가
# 6           361증가              361증가            52증가            1354증가
# 7          3591증가             3591증가           675증가            2561증가
# 8          4041감소             4041감소           757감소             345증가
#
#   2015년06월_계_20~29세 2015년06월_계_30~39세 2015년06월_계_40~49세 2015년06월_계_50~59세  \
# 0            1512감소            5038증가            3962증가            3162감소
# 1              62감소              14감소              35감소              59증가
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(df2015.index)
prob=np.array(df2015["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('age',size=20)
ax.set_ylabel('p&m',size=20)

plt.show()

# %%
fig = plt.figure(figsize=(15,15))
plt.title('대구 연별 인구 변화추이')

ax1 = fig.add_subplot(6, 1, 1)
ax2 = fig.add_subplot(6, 1, 2)
ax3 = fig.add_subplot(6, 1, 3)
ax4 = fig.add_subplot(6, 1, 4)
ax5 = fig.add_subplot(6, 1, 5)
ax6 = fig.add_subplot(6, 1, 6)



ax1.plot(df2015)
ax2.plot(df2016)
ax3.plot(df2017)
ax4.plot(df2018)
ax5.plot(df2019)
ax6.plot(df2020)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)
x_set=np.array(df.index)
day=["201506~201512","201512~201606","201606~201612","201612~201706","201706~201712","201712~201806","201806~201812","201812~201906","201906~201912","201912~202006"]


for i in range(0,10):
    
    prob=np.array(df1[i]["총계"])
    prob1=np.zeros(9,)
    prob2=np.zeros(9,)
    for a in range(0,9):

        if prob[a]>=0:
            prob1[a]=prob[a]

        else:
            prob1[a]=0

    for b in range(0,9):

        if prob[b]<0:
            prob2[b]=prob[b]
        else:
            prob2[b]=0



    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(5, 2, i+1)


    ax.bar(x_set, prob1)
    ax.bar(x_set, prob2,color='r')
    ax.set_xlabel('지역',size=20)
    ax.set_ylabel('인구변화추이',size=20)
    plt.title(day[i])
    ax.plot()



plt.show()

# %%
d2020_2015 = df1[9] - df1[0]
d2020_2015
# Out:
#         총계 연령구간인구수    0~9 10~19  20~29  30~39  40~49  50~59 60~69 70~79 80~89  \
# 대구   -6769   -6769  -4286  1903  -2888   -582  -1545  -3790  -627  4560   297
# 중구    -572    -572   -181    74    209   -137   -215    -89  -258    59   -29
# 동구   -2828   -2828  -1173   280   -684   -534   -448   -673  -396   744    59
# 서구    -601    -601   -258   341   -520   -108    375   -650  -364   511    50
# 남구     685     685    -77   226    380    146      5     98  -308   233   -28
# 북구    1226    1226   -449   510    194    429   -467   -233   330   639   219
# 수성구  -1334   -1334   -254  -403  -1016    444   -583   -122  -211   776    -7
# 달서구     82      82   -687   522   -483    856   -400  -1336   399  1127    32
# 달성군  -3427   -3427  -1207   353   -968  -1678    188   -785   181   471     1
#
#     90~99 100세 이상
# 대구    187       2
# 중구    -11       6
# 동구     -3       0
# 서구     22       0
# 남구     12      -2
# 북구     50       4
# 수성구    45      -3
# 달서구    52       0
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

####################한글
path = '/Windows/Fonts/H2GTRE.TTF'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

####################



x_set=np.array(d2020_2015.index)
prob=np.array(d2020_2015["총계"])
prob1=np.zeros(9,)
prob2=np.zeros(9,)
for i in range(0,9):
    if prob[i]>=0:
        prob1[i]=prob[i]
    else:
        prob1[i]=0

for i in range(0,9):
    if prob[i]<0:
        prob2[i]=prob[i]
    else:
        prob2[i]=0


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.bar(x_set, prob1)
ax.bar(x_set, prob2,color='r')
ax.set_xlabel('지역별',size=20)
ax.set_ylabel('인구증감',size=20)
plt.title("2015~2020 증감추세")

plt.show()
